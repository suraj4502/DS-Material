# %%
import pandas as pd
import numpy as np
import plotly.express as px

# %%
df = pd.read_csv('vgsales.csv')

# %%
df
# Out:
#         Rank                                               Name Platform  \
# 0        259                                          Asteroids     2600
# 1        545                                    Missile Command     2600
# 2       1768                                            Kaboom!     2600
# 3       1971                                           Defender     2600
# 4       2671                                             Boxing     2600
# ...      ...                                                ...      ...
# 16319  16565                                       Mighty No. 9     XOne
# 16320  16572                                 Resident Evil 4 HD     XOne
# 16321  16573                      Farming 2017 - The Simulation      PS4
# 16322  16579                                  Rugby Challenge 3     XOne
# 16323  16592  Chou Ezaru wa Akai Hana: Koi wa Tsuki ni Shiru...      PSV
#
#        Year       Genre             Publisher  NA_Sales  EU_Sales  JP_Sales  \
# ...

# %%
df.isnull().sum()

# %%
df['Publisher'].fillna("Unknown",inplace= True)

# %%
TS = df['Global_Sales'].sum()

# %%
TS

# %%
TG = df.shape[0]

# %%
TG

# %%
TP =len(df['Publisher'].unique())

# %%
TP

# %%
df['Name'].unique()

# %%
fig = px.line(df.groupby('Year')['Global_Sales'].sum().reset_index(), x='Year', y='Global_Sales')
fig.show()

# %%
fig = px.line(df.groupby('Year')['Global_Sales'].sum().reset_index(), x='Year', y='Global_Sales')
fig.update_yaxes(title_text='Global Sales')
fig.update_traces(line=dict(color='red'))
fig.update_layout(
xaxis_title='Year',
yaxis_title='Sales',
width=800,
height=400,
margin=dict(l=10, r=10, t=10, b=10),
xaxis=dict(showgrid=False),
yaxis=dict(showgrid=True, gridcolor='#61677A'),
hovermode='x',  # Show tooltips on hover
hoverlabel=dict(bgcolor='#1A1A40', font_size=12),  # Tooltip style
)
fig.update_layout(plot_bgcolor='#0E1117' ,)
fig.show()

# %%
games_released_over_time = (df.groupby('Year')['Name'].count().reset_index()).rename(columns = {'Name':'count'})
fig = px.bar(games_released_over_time, x='Year', y='count',text_auto=True,
                color_discrete_sequence=['#FCAEAE'])
fig.show()

# %%
# top 10 genres based on GLoabal Sales
temp = df.groupby('Genre')['Global_Sales'].sum().sort_values(ascending = False)
fig = px.bar(temp, x = temp.index,y = temp)
fig.show()

# %%
temp = df.groupby('Platform')['Global_Sales'].sum().sort_values(ascending = False).reset_index().head(10)
fig =px.bar(temp,x='Platform',y= 'Global_Sales')
fig.show()

# %% [markdown]
# ## PUBLISher analysis

# %%
temp = df.groupby("Publisher")['Global_Sales'].sum().reset_index().sort_values("Global_Sales",ascending= False).head(10)
temp
# Out:
#                         Publisher  Global_Sales
# 359                      Nintendo       1784.43
# 138               Electronic Arts       1093.39
# 21                     Activision        721.41
# 455   Sony Computer Entertainment        607.28
# 524                       Ubisoft        473.54
# 493          Take-Two Interactive        399.30
# 487                           THQ        340.44
# 275  Konami Digital Entertainment        278.56
# 445                          Sega        270.66
# 347            Namco Bandai Games        253.65

# %%
fig =px.bar(temp,x = 'Publisher',y= 'Global_Sales')
fig.show()

# %%
px.pie(temp,values='Global_Sales',names= 'Publisher')

# %%
temp =df1.pivot_table(index='Year',columns='Publisher',values='Global_Sales',aggfunc='sum')
temp

# %%
temp.columns

# %%
,color='continent',
       animation_frame='year',
       animation_group='country',

# %%
df1['Global_Sales'].fillna(0,inplace=True)

# %%
df1=df[df['Publisher'].isin(temp.Publisher.unique())]

# %%
px.bar(df1, x='Publisher',y = 'Global_Sales',animation_frame='Year',animation_group='Publisher',range_y=[0,60])
# Out:
# <div>                            <div id="dd664cf9-6e03-4988-ae0d-679f61ac44e9" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("dd664cf9-6e03-4988-ae0d-679f61ac44e9")) {                    Plotly.newPlot(                        "dd664cf9-6e03-4988-ae0d-679f61ac44e9",                        [{"alignmentgroup":"True","hovertemplate":"Year=1980<br>Publisher=%{x}<br>Global_Sales=%{y}<extra></extra>","ids":["Activision","Activision","Activision","Activision","Activision"],"legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":["Activision","Activision","Activision","Activision","Activision"],"xaxis":"x","y":[1.15,0.77,0.49,0.34,0.27],"yaxis":"y","type"
# ...
