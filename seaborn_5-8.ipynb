# %% [markdown]
# ## SEABORN

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# %%
# loading datasets
tips_data = sns.load_dataset('tips')
iris_data = sns.load_dataset("iris")
gap_data = px.data.gapminder()

# %% [markdown]
# # RELATIONAL plots

# %% [markdown]
# - Scatter plot
# - Line plot

# %%
tips_data
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
g = sns.relplot(data=tips_data,
            kind = 'scatter',
            x ='total_bill',
            y = 'tip',
            hue = 'day',
            palette='magma',
            height = 5, 
           aspect=1.6,
               row = 'time',
               col= 'smoker') # figure level chart

g.fig.suptitle("Figure level chart for scatterplot",fontsize = 15,fontweight = 'bold')
plt.show()

# %%
plt.figure(figsize= (10,6))
sns.scatterplot(data=tips_data,
                x ='total_bill',
                y = 'tip',
                hue = 'day',style = 'time',size = 'size') # axis level
plt.show()
# ,hue='day',style='time',size='size'

# %%
g =sns.relplot(data=temp,kind ='line', x='year',y='gdpPercap',hue = 'country',palette='cubehelix',
               col = 'continent',col_wrap=2)
g.fig.suptitle("Figure level chart for lineplot")
plt.show()

# %%
sns.lineplot(data=temp, x='year',y='gdpPercap',hue = 'country',palette='magma', ) # axis level
# Out:
# <Axes: xlabel='year', ylabel='gdpPercap'>

# %%
temp = gap_data[gap_data['country'].isin(["India",'China', 'Pakistan','Poland',"South Africa","Canada"])]
temp
# Out:
#            country continent  year  lifeExp       pop     gdpPercap iso_alpha  \
# 240         Canada  Americas  1952   68.750  14785584  11367.161120       CAN
# 241         Canada  Americas  1957   69.960  17010154  12489.950060       CAN
# 242         Canada  Americas  1962   71.300  18985849  13462.485550       CAN
# 243         Canada  Americas  1967   72.130  20819767  16076.588030       CAN
# 244         Canada  Americas  1972   72.880  22284500  18970.570860       CAN
# ...            ...       ...   ...      ...       ...           ...       ...
# 1411  South Africa    Africa  1987   60.834  35933379   7825.823398       ZAF
# 1412  South Africa    Africa  1992   61.888  39964159   7225.069258       ZAF
# 1413  South Africa    Africa  1997   60.236  42835005   7479.188244       ZAF
# 1414  South Africa    Africa  2002   53.365  44433622   7710.946444       ZAF
# 1415  South Africa    Africa  2007   49.339  43997828   9269.657808       ZAF
#
#       iso_num
# 240       124
# ...

# %% [markdown]
# # Distribution PLots.
# - Histogram.
# - KDE

# %%
sns.kdeplot(data=tips_data, x = 'total_bill', hue= 'sex',
            palette=['r','b'])
# Out:
# <Axes: xlabel='total_bill', ylabel='Density'>

# %%
sns.displot(data=tips_data, x = 'total_bill', hue= 'sex',
            palette=['r','b'],kind='kde',
           col = 'day',col_wrap=2,)
plt.show()  #FIRURE LEVEL

# %%
sns.histplot(data=tips_data, x = 'total_bill',bins = 20, hue= 'sex',palette='vlag') # axis level
# Out:
# <Axes: xlabel='total_bill', ylabel='Count'>

# %%
tips_data
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %% [markdown]
# # CAtegorical plots.
# - barplot
# - boxplot
# - stripplot
# - swarmplot
# - violinplot
# - pichart
# - count

# %%
sns.countplot(data=tips_data,x='day')
# Out:
# <Axes: xlabel='day', ylabel='count'>

# %%
tips_data.groupby('day')['total_bill'].sum()
# Out:
# day
# Thur    1096.33
# Fri      325.88
# Sat     1778.40
# Sun     1627.16
# Name: total_bill, dtype: float64

# %%
sns.catplot(data=tips_data, x='day',y = 'total_bill',
            errorbar=None,estimator='sum',
           palette='magma_r',kind='bar',col= 'sex',row = 'smoker')
plt.show()  # figure level

# %%
sns.barplot(data=tips_data, x='day',y = 'total_bill',
            errorbar=None,estimator='sum',
           palette='magma_r')# axis level
plt.show()

# %%
tips_data
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.catplot(data=tips_data,x='day',y = 'tip',hue = 'sex',kind='box')

# %%
sns.violinplot(data=tips_data,x='day',y = 'tip',hue = 'sex',split=True) # axis level
# Out:
# <Axes: xlabel='day', ylabel='tip'>

# %% [markdown]
# # Pairplot
# # jointplot

# %%
sns.jointplot(data=tips_data,x='total_bill',y = 'tip',kind='scatter')

# %%
sns.pairplot(data=iris_data, hue = 'species')

# %% [markdown]
# # HEATMAP

# %%
temp
# Out:
#            country continent  year  lifeExp       pop     gdpPercap iso_alpha  \
# 240         Canada  Americas  1952   68.750  14785584  11367.161120       CAN
# 241         Canada  Americas  1957   69.960  17010154  12489.950060       CAN
# 242         Canada  Americas  1962   71.300  18985849  13462.485550       CAN
# 243         Canada  Americas  1967   72.130  20819767  16076.588030       CAN
# 244         Canada  Americas  1972   72.880  22284500  18970.570860       CAN
# ...            ...       ...   ...      ...       ...           ...       ...
# 1411  South Africa    Africa  1987   60.834  35933379   7825.823398       ZAF
# 1412  South Africa    Africa  1992   61.888  39964159   7225.069258       ZAF
# 1413  South Africa    Africa  1997   60.236  42835005   7479.188244       ZAF
# 1414  South Africa    Africa  2002   53.365  44433622   7710.946444       ZAF
# 1415  South Africa    Africa  2007   49.339  43997828   9269.657808       ZAF
#
#       iso_num
# 240       124
# ...

# %%
pivot_data =temp.pivot_table(index='year',columns='country',values = 'lifeExp')

# %%
pivot_data
# Out:
# country  Canada     China   India  Pakistan  Poland  South Africa
# year
# 1952     68.750  44.00000  37.373    43.436  61.310        45.009
# 1957     69.960  50.54896  40.249    45.557  65.770        47.985
# 1962     71.300  44.50136  43.605    47.670  67.640        49.951
# 1967     72.130  58.38112  47.193    49.800  69.610        51.927
# 1972     72.880  63.11888  50.651    51.929  70.850        53.696
# 1977     74.210  63.96736  54.208    54.043  70.670        55.527
# 1982     75.760  65.52500  56.596    56.158  71.320        58.161
# 1987     76.860  67.27400  58.553    58.245  70.980        60.834
# 1992     77.950  68.69000  60.223    60.838  70.990        61.888
# 1997     78.610  70.42600  61.765    61.818  72.750        60.236
# 2002     79.770  72.02800  62.879    63.610  74.670        53.365
# 2007     80.653  72.96100  64.698    65.483  75.563        49.339

# %%
sns.heatmap(pivot_data,annot=True,fmt=".2f",cmap='magma')
plt.show()
