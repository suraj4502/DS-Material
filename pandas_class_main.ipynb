# %%
# !pip install pandas

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("Data/sample.csv")

# %%
# series
# dataframe

# %%
df
# Out:
#           name sex   age  height  weight
# 0       Aubrey   M  41.0      74     170
# 1          Ron   M  42.0      68     166
# 2         Carl   M  32.0      70     155
# 3      Antonio   M  39.0      72     167
# 4      Deborah   F  30.0      66     124
# 5   Jacqueline   F  33.0      66     115
# 6        Helen   F  26.0      64     121
# 7        David   M  30.0      71     158
# 8        James   M  53.0      72     175
# 9      Michael   M  32.0      69     143
# 10        Ruth   F  47.0      69     139
# 11        Joel   M  34.0      72     163
# 12       Donna   F  23.0      62      98
# 13       Roger   M  36.0      75     160
# 14         Yao   M   NaN      70     145
# 15   Elizabeth   F  31.0      67     135
# 16         Tim   M  29.0      71     176
# 17       Susan   F  28.0      65     131

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18 entries, 0 to 17
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   name    18 non-null     object
#  1   sex     18 non-null     object
#  2   age     17 non-null     float64
#  3   height  18 non-null     int64
#  4   weight  18 non-null     int64
# dtypes: float64(1), int64(2), object(2)
# memory usage: 852.0+ bytes

# %%
df.head(2)
df.tail(5)
df.sample(5)
# Out:
#        name sex   age  height  weight
# 9   Michael   M  32.0      69     143
# 7     David   M  30.0      71     158
# 11     Joel   M  34.0      72     163
# 4   Deborah   F  30.0      66     124
# 17    Susan   F  28.0      65     131

# %%
df.describe()
# Out:
#              age     height      weight
# count  17.000000  18.000000   18.000000
# mean   34.470588  69.055556  146.722222
# std     7.763035   3.522570   22.540958
# min    23.000000  62.000000   98.000000
# 25%    30.000000  66.250000  132.000000
# 50%    32.000000  69.500000  150.000000
# 75%    39.000000  71.750000  165.250000
# max    53.000000  75.000000  176.000000

# %%
df.set_index('name',inplace= True)

# %%
df
# Out:
#            sex   age  height  weight
# name
# Aubrey       M  41.0      74     170
# Ron          M  42.0      68     166
# Carl         M  32.0      70     155
# Antonio      M  39.0      72     167
# Deborah      F  30.0      66     124
# Jacqueline   F  33.0      66     115
# Helen        F  26.0      64     121
# David        M  30.0      71     158
# James        M  53.0      72     175
# Michael      M  32.0      69     143
# Ruth         F  47.0      69     139
# Joel         M  34.0      72     163
# Donna        F  23.0      62      98
# Roger        M  36.0      75     160
# Yao          M   NaN      70     145
# Elizabeth    F  31.0      67     135
# Tim          M  29.0      71     176
# Susan        F  28.0      65     131

# %%
df.loc['Jacqueline':'Michael',['sex','age',]]
# Out:
#            sex   age
# name
# Jacqueline   F  33.0
# Helen        F  26.0
# David        M  30.0
# James        M  53.0
# Michael      M  32.0

# %%
df.reset_index(inplace=True)

# %%
df
# Out:
#           name sex   age  height  weight
# 0       Aubrey   M  41.0      74     170
# 1          Ron   M  42.0      68     166
# 2         Carl   M  32.0      70     155
# 3      Antonio   M  39.0      72     167
# 4      Deborah   F  30.0      66     124
# 5   Jacqueline   F  33.0      66     115
# 6        Helen   F  26.0      64     121
# 7        David   M  30.0      71     158
# 8        James   M  53.0      72     175
# 9      Michael   M  32.0      69     143
# 10        Ruth   F  47.0      69     139
# 11        Joel   M  34.0      72     163
# 12       Donna   F  23.0      62      98
# 13       Roger   M  36.0      75     160
# 14         Yao   M   NaN      70     145
# 15   Elizabeth   F  31.0      67     135
# 16         Tim   M  29.0      71     176
# 17       Susan   F  28.0      65     131

# %%
# iloc 
df.iloc[5:10,[0,2,3,4]]
# Out:
#          name   age  height  weight
# 5  Jacqueline  33.0      66     115
# 6       Helen  26.0      64     121
# 7       David  30.0      71     158
# 8       James  53.0      72     175
# 9     Michael  32.0      69     143

# %%
df.columns
# Out:
# Index(['name', 'sex', 'age', 'height', 'weight'], dtype='object')

# %%
df['name'].unique()
# Out:
# array(['Aubrey', 'Ron', 'Carl', 'Antonio', 'Deborah', 'Jacqueline',
#        'Helen', 'David', 'James', 'Michael', 'Ruth', 'Joel', 'Donna',
#        'Roger', 'Yao', 'Elizabeth', 'Tim', 'Susan'], dtype=object)

# %%
df[df['age'] > 35]
# Out:
#        name sex   age  height  weight
# 0    Aubrey   M  41.0      74     170
# 1       Ron   M  42.0      68     166
# 3   Antonio   M  39.0      72     167
# 8     James   M  53.0      72     175
# 10     Ruth   F  47.0      69     139
# 13    Roger   M  36.0      75     160

# %%
pd.set_option('display.max_columns', None)

# %%
ipl = pd.read_csv('Data/ipl-matches.csv')
movies = pd.read_csv('Data/movies.csv')

# %%
cond = ipl['MatchNumber'] == 'Final'
ipl[cond][['Season','WinningTeam']]
# Out:
#       Season            WinningTeam
# 0       2022         Gujarat Titans
# 74      2021    Chennai Super Kings
# 134  2020/21         Mumbai Indians
# 194     2019         Mumbai Indians
# 254     2018    Chennai Super Kings
# 314     2017         Mumbai Indians
# 373     2016    Sunrisers Hyderabad
# 433     2015         Mumbai Indians
# 492     2014  Kolkata Knight Riders
# 552     2013         Mumbai Indians
# 628     2012  Kolkata Knight Riders
# 702     2011    Chennai Super Kings
# 775  2009/10    Chennai Super Kings
# 835     2009        Deccan Chargers
# 892  2007/08       Rajasthan Royals

# %%
# find all the final winners
ipl[ipl['MatchNumber'] == 'Final'][['Season','WinningTeam']]
# value_counts()
# Out:
#       Season            WinningTeam
# 0       2022         Gujarat Titans
# 74      2021    Chennai Super Kings
# 134  2020/21         Mumbai Indians
# 194     2019         Mumbai Indians
# 254     2018    Chennai Super Kings
# 314     2017         Mumbai Indians
# 373     2016    Sunrisers Hyderabad
# 433     2015         Mumbai Indians
# 492     2014  Kolkata Knight Riders
# 552     2013         Mumbai Indians
# 628     2012  Kolkata Knight Riders
# 702     2011    Chennai Super Kings
# 775  2009/10    Chennai Super Kings
# 835     2009        Deccan Chargers
# 892  2007/08       Rajasthan Royals

# %%
ipl[ipl['SuperOver'] == 'Y'].shape[0]
# Out:
# 14

# %%
ipl[ipl['MatchNumber'] == 'Final'][['WinningTeam']].value_counts()
# Out:
# WinningTeam
# Mumbai Indians           5
# Chennai Super Kings      4
# Kolkata Knight Riders    2
# Deccan Chargers          1
# Gujarat Titans           1
# Rajasthan Royals         1
# Sunrisers Hyderabad      1
# dtype: int64

# %%
ipl[ipl['SuperOver']=='Y'].shape[0]

# %%
# how many super over finishes have occured
ipl['SuperOver'].unique()
ipl[ipl['SuperOver'] == 'Y'].shape[0]
# Out:
# 14

# %%
ipl
# Out:
#           ID        City        Date   Season  MatchNumber  \
# 0    1312200   Ahmedabad  2022-05-29     2022        Final
# 1    1312199   Ahmedabad  2022-05-27     2022  Qualifier 2
# 2    1312198     Kolkata  2022-05-25     2022   Eliminator
# 3    1312197     Kolkata  2022-05-24     2022  Qualifier 1
# 4    1304116      Mumbai  2022-05-22     2022           70
# ..       ...         ...         ...      ...          ...
# 945   335986     Kolkata  2008-04-20  2007/08            4
# 946   335985      Mumbai  2008-04-20  2007/08            5
# 947   335984       Delhi  2008-04-19  2007/08            3
# 948   335983  Chandigarh  2008-04-19  2007/08            2
# 949   335982   Bangalore  2008-04-18  2007/08            1
#
#                            Team1                        Team2  \
# 0               Rajasthan Royals               Gujarat Titans
# 1    Royal Challengers Bangalore             Rajasthan Royals
# 2    Royal Challengers Bangalore         Lucknow Super Giants
# ...

# %%
# Out:
# 0      False
# 1      False
# 2       True
# 3      False
# 4      False
#        ...
# 945    False
# 946     True
# 947    False
# 948    False
# 949    False
# Name: WinningTeam, Length: 950, dtype: bool

# %%
ipl
# Out:
#           ID        City        Date   Season  MatchNumber  \
# 0    1312200   Ahmedabad  2022-05-29     2022        Final
# 1    1312199   Ahmedabad  2022-05-27     2022  Qualifier 2
# 2    1312198     Kolkata  2022-05-25     2022   Eliminator
# 3    1312197     Kolkata  2022-05-24     2022  Qualifier 1
# 4    1304116      Mumbai  2022-05-22     2022           70
# ..       ...         ...         ...      ...          ...
# 945   335986     Kolkata  2008-04-20  2007/08            4
# 946   335985      Mumbai  2008-04-20  2007/08            5
# 947   335984       Delhi  2008-04-19  2007/08            3
# 948   335983  Chandigarh  2008-04-19  2007/08            2
# 949   335982   Bangalore  2008-04-18  2007/08            1
#
#                            Team1                        Team2  \
# 0               Rajasthan Royals               Gujarat Titans
# 1    Royal Challengers Bangalore             Rajasthan Royals
# 2    Royal Challengers Bangalore         Lucknow Super Giants
# ...

# %%
ipl[(ipl['City'] == 'Bangalore') & (ipl['WinningTeam'] == 'Royal Challengers Bangalore')].shape[0]
# Out:
# 29

# %%
# how many matches has RCB won in Banglore
mask1 = ipl['City'] == 'Bangalore'
mask2 = ipl['WinningTeam']== 'Royal Challengers Bangalore'

print(f"THE total number matches won by RCB in Banglore is {ipl[mask1 & mask2].shape[0]}.")
# Out:
# THE total number matches won by RCB in Banglore is 29.

# %%
ipl[ipl['TossWinner'] == ipl['WinningTeam']]
# Out:
#           ID         City        Date   Season  MatchNumber  \
# 1    1312199    Ahmedabad  2022-05-27     2022  Qualifier 2
# 3    1312197      Kolkata  2022-05-24     2022  Qualifier 1
# 5    1304115       Mumbai  2022-05-21     2022           69
# 8    1304112  Navi Mumbai  2022-05-18     2022           66
# 11   1304109       Mumbai  2022-05-15     2022           63
# ..       ...          ...         ...      ...          ...
# 935   335996    Bangalore  2008-04-28  2007/08           15
# 937   335994       Mumbai  2008-04-27  2007/08           14
# 939   335992    Bangalore  2008-04-26  2007/08           12
# 941   335990    Hyderabad  2008-04-24  2007/08            9
# 948   335983   Chandigarh  2008-04-19  2007/08            2
#
#                            Team1                  Team2  \
# 1    Royal Challengers Bangalore       Rajasthan Royals
# 3               Rajasthan Royals         Gujarat Titans
# 5                 Delhi Capitals         Mumbai Indians
# ...

# %%
a = ipl[ipl['TossWinner'] == ipl['WinningTeam']].shape[0]
b = ipl.shape[0]
a/b * 100

# %%
# toss winner is match winner in percentage
toss_winner = ipl[ipl['TossWinner'] == ipl['WinningTeam']].shape[0]
total_matches = ipl.shape[0]

np.round((toss_winner/total_matches) * 100,decimals=2)
# Out:
# 51.47

# %%
# movies with rating higher than 8 and votes>10000
movies[(movies['imdb_rating'] > 8) & (movies['imdb_votes'] > 10000)]['title_x']
# Out:
# 0          Uri: The Surgical Strike
# 11                        Gully Boy
# 37                Article 15 (film)
# 40                  Super 30 (film)
# 143                         Tumbbad
# 146                       Andhadhun
# 325                Pink (2016 film)
# 354                   Dangal (film)
# 418                          Masaan
# 426            Drishyam (2015 film)
# 436                   Talvar (film)
# 469               Queen (2014 film)
# 536                   Haider (film)
# 566                     Ugly (film)
# 567                       PK (film)
# 589                    Vishwaroopam
# 612              Bhaag Milkha Bhaag
# 638                   Shahid (film)
# 668         Paan Singh Tomar (film)
# 669                         Kahaani
# 693              Gangs of Wasseypur
# 694     Gangs of Wasseypur – Part 2
# 709                          Barfi!
# 714                OMG – Oh My God!
# 778        Zindagi Na Milegi Dobara
# 869               Udaan (2010 film)
# ...

# %%
movies[(movies['genres'].str.split("|").apply(lambda x : 'Action' in x)) & (movies['imdb_rating'] > 7.5)]['title_x']

# %%
l= [ 'Drama', 'War']
'Action' in l

# %%
movies['genres'].str.contains('Action')

# %%
# Action movies with rating higher than 7.5
temp = movies[movies['genres'].str.split("|").apply(lambda x : "Action" in x)]

# %%
temp[temp['imdb_rating'] > 7.5]['title_x']

# %%
action_checker = lambda x : "Action" in x

# %%
action_checker(['Drama', 'Romance'])

# %%
c1 = movies['genres'].str.contains('Action')
c2 = movies['imdb_rating'] > 8
movies[(c1) & (c2)].shape

# %%
# value_counts 
data = {
    'Category': ['A', 'B', 'A', 'C', 'B', 'A', 'A', 'C', 'B', 'B']
}

df = pd.DataFrame(data)
df

# %%
df.value_counts()

# %%
ipl['WinningTeam'].value_counts().sort_values(ascending=False)

# %%
ipl['MatchNumber'].unique()

# %%
ipl[~ipl['MatchNumber'].str.isdigit()]['Player_of_Match'].value_counts()

# %%
ipl[~ipl['MatchNumber'].str.isdigit()]['Player_of_Match'].value_counts()

# %%
ipl[ipl['MatchNumber'].isin(['Final','Semi Final',])]['Player_of_Match'].value_counts()

# %%
# find which player has won most man of the match in finals and semifinals
ipl[ipl['MatchNumber'].isin(['Final','Semi Final',])]['Player_of_Match'].value_counts()

# %%
# After winning toss what the winning team prefers
ipl['TossDecision'].value_counts().reset_index().iloc[0,0]
ipl['TossDecision'].value_counts().plot(kind="pie")

# %%
# how many matches each team has played
ipl[['Team1','Team2']]
(ipl['Team1'].value_counts()  + ipl['Team2'].value_counts()).sort_values(ascending=False)

# %%
# sorting

# %%
movies.sort_values(['runtime'],ascending=False,na_position='last')

# %%
movies.sort_values(['year_of_release','title_x'],ascending=[False,True])[['year_of_release','title_x']]

# %%
df = pd.read_excel('Data/fighter_details.xlsx')

# %%
# pip install openpyxl

# %%
pd.set_option('display.max_columns', None)

# %%
df

# %%
df[df['Name'] =='Charles Oliveira']

# %%
df.info()

# %%
# rename

df.rename(columns={'Division Title' : "Division",
                  'Division Body_Wins' : 'Wins',
                  'Division Body_Losses' : 'Losses',
                  'Division Body_Draws' : "Draws"},inplace=True)

# %%
# set index
df.set_index('Name',inplace=True)

# %%
df.loc['Randy Couture']

# %%
df.reset_index(inplace=True)

# %%
df

# %%
# unique --> couonts null
ipl['Season'].nunique()

# %%
df['Nickname'].replace({'Null': None},inplace=True)

# %%
df['Nickname'].isnull().sum()

# %%
df['Nickname'].notnull().sum()

# %%
df.Name.hasnans

# %%
# dropna
data = {
    'Name': ['Alice', 'Bob', 'Charlie', 'David'],
    'Age': [25, None, 30, 22],
    'Score': [85, 92, None, 78],
    'Gender': ['Female', 'Male', None, 'Male']
}
temp = pd.DataFrame(data)
temp

# %%
temp.dropna(how="all")

# %%
temp.dropna(axis=1,how="all")

# %%
temp.dropna(subset=["Age","Gender"])

# %%
#fillna
temp.fillna(0)
temp.fillna(temp['Age'].mean())

# %%
temp

# %%
temp.fillna(method='ffill')  # Forward fill

# %%
temp.fillna(method = 'bfill')

# %%
temp.interpolate()

# %%
data = {
    'Name': ['Alice', 'Bob', 'Charlie', 'David', 'Alice', 'Eva', 'Bob','Nate'],
    'Age': [25, 30, 22, 28, 25, 26, 30,30],
    'Score': [85, 92, 78, 80, 85, 90, 92,92]
}

temp = pd.DataFrame(data)
temp

# %%
temp.duplicated()

# %%
~temp.duplicated()

# %%
temp[~temp.duplicated()]

# %%
temp.drop_duplicates()

# %%
temp.drop_duplicates(subset=['Age','Score'])

# %%
temp.drop_duplicates(subset=['Score'])

# %%
temp

# %%
temp.drop_duplicates(keep=False)

# %%
# find the last match played by MS Dhoni in Chennai

# %%
ipl

# %%
ipl['Team1Players'][15]

# %%
# find the last match played by virat kohli in Delhi
ipl['All_players'] = ipl['Team1Players'] + ipl['Team2Players']
ipl.head()

# %%
l=['R Sharma','MS Dhoni']

# %%
ipl['All_players'].apply(lambda x :'V Kohli' in x )

# %%
ipl['Did_Kohli_played'] = ipl['All_players'].str.contains('V Kohli')
ipl['Did_Dhoni_played'] = ipl['All_players'].str.contains('MS Dhoni')

# %%
mask1 = ipl['All_players'].str.contains('MS Dhoni')
mask2 = ipl['City'] == 'Chennai'

ipl[mask1 & mask2].sort_values('Date').drop_duplicates(subset=['City','Did_Dhoni_played'],keep = 'last')

# %%
mask1 = ipl['All_players'].str.contains('V Kohli')
mask2 = ipl['City'] == 'Delhi'

ipl[mask1 & mask2].sort_values('Date').drop_duplicates(subset=['City','Did_Kohli_played'],keep = 'last')

# %%
movies.duplicated().sum()

# %% [markdown]
# ---

# %%
movies = pd.read_csv('Data/imdb-top-1000.csv')

# %%
movies.head()

# %%
movies.iloc[863]

# %%
movies.groupby('Released_Year').get_group('1962').sort_values('Gross',ascending= False)

# %%
movies.groupby('Released_Year').get_group('1962')['Gross'].idxmax()

# %%
# find the total earnings by each year
movies.groupby('Released_Year')['Gross'].sum().sort_values(ascending= False)[0:3]

# %%
# find the top 3 genres by total earning
movies.groupby('Genre')['Gross'].sum().sort_values(ascending= False)[0:3]

# %%
# find the genre with highest avg IMDB rating
movies.groupby('Genre')['IMDB_Rating'].mean().sort_values(ascending = False)

# %%
movies.groupby(by= 'Released_Year')['Series_Title'].count().sort_index(ascending= False)[1:]

# %%
# find director with most popularity
movies.groupby('Director')['No_of_Votes'].sum().sort_values(ascending=False).idxmax()

# %%
# find number of movies done by each actor
# movies['Star1'].value_counts()
movies.groupby('Star1')['Series_Title'].count().sort_values(ascending=False).head(1)

# %%
# ACTORS WITH HIGHEST EARNINGS
movies.groupby('Star1')['Gross'].sum().sort_values(ascending=False).head().reset_index()

# %%
movies['Star1'].value_counts()

# %%
# get_group
movies.groupby('Genre').get_group('Drama')

# %%
movies

# %%
# Highest total income by a director star duo
movies.groupby(['Director','Star1'])['Gross'].sum().sort_values(ascending=False)

# %%
movies.groupby(['Director','Star1']).get_group(('Christopher Nolan','Christian Bale'))

# %%
df = pd.read_excel('Data/fighter_details.xlsx')
df

# %%
df.rename(columns={'Division Title' : 'Division',
                  'Division Body_Wins':'Wins',
                  'Division Body_Losses' : 'Losses',
                  'Division Body_Draws': 'Draws'},inplace=True)

# %%
df.head()

# %%
# Calculate the average age of athletes in each division.
df.groupby('Division')['Bio Data_Age'].mean().sort_values(ascending=False)

# %%
df.info()

# %%
df['Losses'].isnull().sum()

# %%
df['Losses'].unique()

# %%
df['Wins'] = df['Wins'].replace('Null', pd.NA)
df['Wins'] = pd.to_numeric(df['Wins'], errors='coerce')

# %%
df['Losses'] = df['Losses'].replace({'Null': pd.NA,'<NA>':pd.NA})
df['Losses'] = pd.to_numeric(df['Losses'], errors='coerce')

# %%
# Calculate the total number of wins and losses for each division.
df.groupby('Division')[['Wins','Losses']].sum()

# %%
df['Bio Data_Fighting style'].fillna('unknown',inplace=True)

# %%
df['Bio Data_Fighting style'].isnull().sum()

# %%
df['Bio Data_Fighting style'].unique()

# %%
# Find the most common fighting style among athletes.
temp = df.groupby("Bio Data_Fighting style")['Name'].count().reset_index()

# %%
result = temp.nlargest(2,'Name').iloc[-1]['Bio Data_Fighting style']
print(f"The most common fighting styles among the atheletes is {result}.")

# %%
df.groupby('Bio Data_Fighting style')['Name'].count().idxmax()

# %%
df.head()

# %%
# Calculate the average striking accuracy for athletes in different age groups.
# Define the bins
bins = [20, 30, 40, 50, 60]

df['Age_Category']= pd.cut(df['Bio Data_Age'], bins)

# %%
df['Age_Category'].unique()

# %%
df['Striking accuracy']= df['Striking accuracy'].str.rstrip("%").astype(float)

# %%
df['Striking accuracy'].fillna(0,inplace=True)

# %%
df.groupby('Age_Category')['Striking accuracy'].mean()

# %%
df.groupby('Division')['Striking accuracy'].mean()

# %%
df['']

# %%
# Count the number of athletes in each combination of fighting style and division.
df.groupby(['Division','Bio Data_Fighting style'])['Name'].count().reset_index()
#.pivot(index='Division',columns='Bio Data_Fighting style')

# %%
df.pivot_table(index='Division',columns='Bio Data_Fighting style',values='Name',aggfunc='count')

# %%
df.pivot_table(index='Division',columns='Bio Data_Fighting style',values='Bio Data_Age',aggfunc='mean')

# %%
import seaborn as sns
tips_data = sns.load_dataset('tips')
tips_data

# %%
tips_data.groupby(['sex','smoker'])['total_bill'].mean()

# %%
tips_data.pivot_table(index='sex', columns='smoker',values='total_bill', aggfunc='mean',margins=True)

# %%
# Create sample data
students = pd.DataFrame({
    'Student_ID': [101, 102, 103, 104, 105, 106],
    'Name': ['Alice', 'Bob', 'Charlie', 'David', 'Eve','nate']
})

scores = pd.DataFrame({
    'Student_ID': [101, 102, 103, 104, 105,107],
    'Math_Score': [85, 90, 75, 88, 92,88],
    'Science_Score': [78, 85, 70, 92, 85,99]
})

courses = pd.DataFrame({
    'Course_ID': [1, 2, 3],
    'Course_Name': ['Math', 'Science', 'History']
})

enrollments = pd.DataFrame({
    'Student_ID': [101, 102, 103, 105],
    'Course_ID': [1, 2, 3, 1]
})

# %%
students

# %%
scores

# %%
courses

# %%
enrollments

# %%
## Merge
pd.merge(students, scores, on='Student_ID', how='inner')

# %%
pd.merge(students, scores, on='Student_ID', how='outer')

# %%
merged_data = pd.merge(enrollments, courses, on='Course_ID')
merged_data

# %%
merged_data = pd.merge(merged_data, students, on='Student_ID')
merged_data= pd.merge(merged_data, scores, on='Student_ID')
merged_data

# %%
students

# %%
scores

# %%
pd.concat([students, scores] , axis=1)

# %%
pd.concat([students, scores])
